# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Data source**: https://sdmx.data.unicef.org/databrowser/index.html (UNICEF)
#
# **Period**: from 2000-12-31 to 2021-12-31

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fbf32101-c29c-4cb2-90cb-b11c34b77007" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fbf32101-c29c-4cb2-90cb-b11c34b77007">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('/content/NUTRITION (1) (1).csv')
df
# Out:
#                                DATAFLOW REF_AREA:Geographic area  \
# 0      UNICEF:NUTRITION(1.0): Nutrition           IDN: Indonesia
# 1      UNICEF:NUTRITION(1.0): Nutrition           IDN: Indonesia
# 2      UNICEF:NUTRITION(1.0): Nutrition           IDN: Indonesia
# 3      UNICEF:NUTRITION(1.0): Nutrition           IDN: Indonesia
# 4      UNICEF:NUTRITION(1.0): Nutrition           IDN: Indonesia
# ...                                 ...                      ...
# 10955  UNICEF:NUTRITION(1.0): Nutrition           IDN: Indonesia
# 10956  UNICEF:NUTRITION(1.0): Nutrition           IDN: Indonesia
# 10957  UNICEF:NUTRITION(1.0): Nutrition           IDN: Indonesia
# 10958  UNICEF:NUTRITION(1.0): Nutrition           IDN: Indonesia
# 10959  UNICEF:NUTRITION(1.0): Nutrition           IDN: Indonesia
#
#                                      INDICATOR:Indicator    SEX:Sex  \
# 0      NT_BF_CBF_12_15: Continued breastfeeding (12-1...  F: Female
# ...

# %%
df = pd.DataFrame(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10960 entries, 0 to 10959
# Data columns (total 30 columns):
#  #   Column                                                                          Non-Null Count  Dtype
# ---  ------                                                                          --------------  -----
#  0   DATAFLOW                                                                        10960 non-null  object
#  1   REF_AREA:Geographic area                                                        10960 non-null  object
#  2   INDICATOR:Indicator                                                             10960 non-null  object
#  3   SEX:Sex                                                                         10960 non-null  object
#  4   AGE:Current age                                                                 10960 non-null  object
#  5   WEALTH_QUINTILE:Wealth Quintile                                                 10960 non-null  object
# ...

# %%
df = df.rename(columns={'REF_AREA:Geographic area': 'Area', 'INDICATOR:Indicator': 'Indicator', 'SEX:Sex':'Sex', 'AGE:Current age':'Age', 'WEALTH_QUINTILE:Wealth Quintile': 'Wealth', "MATERNAL_EDU_LVL:Mother's Education Level": "Maternal Edu Level", 'TIME_PERIOD:Time period': 'Period', 'UNIT_MEASURE:Unit of measure' : 'Unit of Measure'})
df
# Out:
#                                DATAFLOW            Area  \
# 0      UNICEF:NUTRITION(1.0): Nutrition  IDN: Indonesia
# 1      UNICEF:NUTRITION(1.0): Nutrition  IDN: Indonesia
# 2      UNICEF:NUTRITION(1.0): Nutrition  IDN: Indonesia
# 3      UNICEF:NUTRITION(1.0): Nutrition  IDN: Indonesia
# 4      UNICEF:NUTRITION(1.0): Nutrition  IDN: Indonesia
# ...                                 ...             ...
# 10955  UNICEF:NUTRITION(1.0): Nutrition  IDN: Indonesia
# 10956  UNICEF:NUTRITION(1.0): Nutrition  IDN: Indonesia
# 10957  UNICEF:NUTRITION(1.0): Nutrition  IDN: Indonesia
# 10958  UNICEF:NUTRITION(1.0): Nutrition  IDN: Indonesia
# 10959  UNICEF:NUTRITION(1.0): Nutrition  IDN: Indonesia
#
#                                                Indicator        Sex  \
# 0      NT_BF_CBF_12_15: Continued breastfeeding (12-1...  F: Female
# 1      NT_BF_CBF_12_15: Continued breastfeeding (12-1...  F: Female
# 2      NT_BF_CBF_12_15: Continued breastfeeding (12-1...  F: Female
# ...
